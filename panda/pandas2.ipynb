# %%
import pandas as pd
import numpy as np

# %%
st_per = pd.read_csv('social_media_engagement1.csv')
st_per
# Out:
#     post_id   platform post_type         post_time  likes  comments  shares  \
# 0         1   Facebook     image   8/17/2023 14:45   2121       474     628
# 1         2   Facebook  carousel    5/14/2023 0:45   3660       432     694
# 2         3  Instagram      poll   2/21/2023 16:15   4955       408     688
# 3         4    Twitter     image   11/16/2023 0:45   1183        90     187
# 4         5    Twitter     video    5/23/2023 0:30   3499       247     286
# ..      ...        ...       ...               ...    ...       ...     ...
# 95       96  Instagram  carousel   7/12/2023 17:45     36       294     911
# 96       97    Twitter     video  10/27/2023 23:45    314       108     458
# 97       98    Twitter      text     8/5/2023 8:45    229       179      38
# 98       99  Instagram      poll  12/29/2023 12:15   5000       500     204
# 99      100  Instagram     image    6/6/2023 21:00   4483       357      25
#
#      post_day sentiment_score
# ...

# %%
#feacher selection tecniq
st_per['likes']
# Out:
# 0     2121
# 1     3660
# 2     4955
# 3     1183
# 4     3499
#       ...
# 95      36
# 96     314
# 97     229
# 98    5000
# 99    4483
# Name: likes, Length: 100, dtype: int64

# %%
st_per[['post_id',	'platform',	'post_type',	'post_time']]
# Out:
#     post_id   platform post_type         post_time
# 0         1   Facebook     image   8/17/2023 14:45
# 1         2   Facebook  carousel    5/14/2023 0:45
# 2         3  Instagram      poll   2/21/2023 16:15
# 3         4    Twitter     image   11/16/2023 0:45
# 4         5    Twitter     video    5/23/2023 0:30
# ..      ...        ...       ...               ...
# 95       96  Instagram  carousel   7/12/2023 17:45
# 96       97    Twitter     video  10/27/2023 23:45
# 97       98    Twitter      text     8/5/2023 8:45
# 98       99  Instagram      poll  12/29/2023 12:15
# 99      100  Instagram     image    6/6/2023 21:00
#
# [100 rows x 4 columns]

# %%
new_data=st_per[['post_id',	'platform'	,'post_type'	,'post_time']]
new_data
# Out:
#     post_id   platform post_type         post_time
# 0         1   Facebook     image   8/17/2023 14:45
# 1         2   Facebook  carousel    5/14/2023 0:45
# 2         3  Instagram      poll   2/21/2023 16:15
# 3         4    Twitter     image   11/16/2023 0:45
# 4         5    Twitter     video    5/23/2023 0:30
# ..      ...        ...       ...               ...
# 95       96  Instagram  carousel   7/12/2023 17:45
# 96       97    Twitter     video  10/27/2023 23:45
# 97       98    Twitter      text     8/5/2023 8:45
# 98       99  Instagram      poll  12/29/2023 12:15
# 99      100  Instagram     image    6/6/2023 21:00
#
# [100 rows x 4 columns]

# %%
#column
st_per.columns
# Out:
# Index(['post_id', 'platform', 'post_type', 'post_time', 'likes', 'comments',
#        'shares', 'post_day', 'sentiment_score'],
#       dtype='object')

# %%
st_per.info
# Out:
# <bound method DataFrame.info of     post_id   platform post_type         post_time  likes  comments  shares  \
# 0         1   Facebook     image   8/17/2023 14:45   2121       474     628
# 1         2   Facebook  carousel    5/14/2023 0:45   3660       432     694
# 2         3  Instagram      poll   2/21/2023 16:15   4955       408     688
# 3         4    Twitter     image   11/16/2023 0:45   1183        90     187
# 4         5    Twitter     video    5/23/2023 0:30   3499       247     286
# ..      ...        ...       ...               ...    ...       ...     ...
# 95       96  Instagram  carousel   7/12/2023 17:45     36       294     911
# 96       97    Twitter     video  10/27/2023 23:45    314       108     458
# 97       98    Twitter      text     8/5/2023 8:45    229       179      38
# 98       99  Instagram      poll  12/29/2023 12:15   5000       500     204
# 99      100  Instagram     image    6/6/2023 21:00   4483       357      25
#
# ...

# %%
st_per.select_dtypes(include=int)
# Out:
#     post_id  likes  comments  shares
# 0         1   2121       474     628
# 1         2   3660       432     694
# 2         3   4955       408     688
# 3         4   1183        90     187
# 4         5   3499       247     286
# ..      ...    ...       ...     ...
# 95       96     36       294     911
# 96       97    314       108     458
# 97       98    229       179      38
# 98       99   5000       500     204
# 99      100   4483       357      25
#
# [100 rows x 4 columns]

# %%
st_per.select_dtypes(include='number')
# Out:
#     post_id  likes  comments  shares
# 0         1   2121       474     628
# 1         2   3660       432     694
# 2         3   4955       408     688
# 3         4   1183        90     187
# 4         5   3499       247     286
# ..      ...    ...       ...     ...
# 95       96     36       294     911
# 96       97    314       108     458
# 97       98    229       179      38
# 98       99   5000       500     204
# 99      100   4483       357      25
#
# [100 rows x 4 columns]

# %%
st_per.select_dtypes(include='object')
# Out:
#      platform post_type         post_time   post_day sentiment_score
# 0    Facebook     image   8/17/2023 14:45   Thursday        positive
# 1    Facebook  carousel    5/14/2023 0:45     Sunday         neutral
# 2   Instagram      poll   2/21/2023 16:15    Tuesday        negative
# 3     Twitter     image   11/16/2023 0:45   Thursday        negative
# 4     Twitter     video    5/23/2023 0:30    Tuesday        positive
# ..        ...       ...               ...        ...             ...
# 95  Instagram  carousel   7/12/2023 17:45  Wednesday        positive
# 96    Twitter     video  10/27/2023 23:45     Friday         neutral
# 97    Twitter      text     8/5/2023 8:45   Saturday        positive
# 98  Instagram      poll  12/29/2023 12:15     Friday        positive
# 99  Instagram     image    6/6/2023 21:00    Tuesday         neutral
#
# [100 rows x 5 columns]

# %%
st_per.select_dtypes(exclude='number')
# Out:
#      platform post_type         post_time   post_day sentiment_score
# 0    Facebook     image   8/17/2023 14:45   Thursday        positive
# 1    Facebook  carousel    5/14/2023 0:45     Sunday         neutral
# 2   Instagram      poll   2/21/2023 16:15    Tuesday        negative
# 3     Twitter     image   11/16/2023 0:45   Thursday        negative
# 4     Twitter     video    5/23/2023 0:30    Tuesday        positive
# ..        ...       ...               ...        ...             ...
# 95  Instagram  carousel   7/12/2023 17:45  Wednesday        positive
# 96    Twitter     video  10/27/2023 23:45     Friday         neutral
# 97    Twitter      text     8/5/2023 8:45   Saturday        positive
# 98  Instagram      poll  12/29/2023 12:15     Friday        positive
# 99  Instagram     image    6/6/2023 21:00    Tuesday         neutral
#
# [100 rows x 5 columns]

# %%
st_per['comments'][0]
# Out:
# np.int64(474)

# %%
st_per['comments'][4]
# Out:
# np.int64(247)

# %%
st_per['shares'][40:50]
# Out:
# 40    461
# 41    730
# 42     85
# 43    177
# 44    118
# 45    427
# 46    993
# 47     16
# 48    298
# 49    127
# Name: shares, dtype: int64

# %%
st_per[['shares','comments']][40:50]
# Out:
#     shares  comments
# 40     461       176
# 41     730       252
# 42      85        97
# 43     177        50
# 44     118       132
# 45     427       380
# 46     993        44
# 47      16       232
# 48     298       169
# 49     127       206

# %%
st_per["shares"][1]=324
# Out:
# C:\Users\vasud\AppData\Local\Temp\ipykernel_20108\4228559675.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   st_per["shares"][1]=324
# ...

# %%
st_per
# Out:
#     post_id   platform post_type         post_time  likes  comments  shares  \
# 0         1   Facebook     image   8/17/2023 14:45   2121       474     628
# 1         2   Facebook  carousel    5/14/2023 0:45   3660       432     324
# 2         3  Instagram      poll   2/21/2023 16:15   4955       408     688
# 3         4    Twitter     image   11/16/2023 0:45   1183        90     187
# 4         5    Twitter     video    5/23/2023 0:30   3499       247     286
# ..      ...        ...       ...               ...    ...       ...     ...
# 95       96  Instagram  carousel   7/12/2023 17:45     36       294     911
# 96       97    Twitter     video  10/27/2023 23:45    314       108     458
# 97       98    Twitter      text     8/5/2023 8:45    229       179      38
# 98       99  Instagram      poll  12/29/2023 12:15   5000       500     204
# 99      100  Instagram     image    6/6/2023 21:00   4483       357      25
#
#      post_day sentiment_score
# ...

# %%
st_per.loc[(st_per.platform=="Twitter")]
# Out:
#     post_id platform post_type         post_time  likes  comments  shares  \
# 3         4  Twitter     image   11/16/2023 0:45   1183        90     187
# 4         5  Twitter     video    5/23/2023 0:30   3499       247     286
# 9        10  Twitter  carousel   5/11/2023 11:00   1878       225     438
# 10       11  Twitter      text    12/8/2023 2:15   1446        44      52
# 11       12  Twitter     video    6/15/2023 3:15    304        42      89
# 13       14  Twitter      text   9/30/2023 10:30   1333       144     123
# 15       16  Twitter     image   2/10/2023 13:00   2348       154      18
# 17       18  Twitter      text    7/23/2023 5:45    512       123     338
# 18       19  Twitter      text   11/20/2023 2:00   2013       122     183
# 20       21  Twitter      poll     5/2/2023 6:15    559       136      55
# 21       22  Twitter  carousel   1/30/2023 13:30   1961        44     439
# 22       23  Twitter      text   10/2/2023 12:15    332       109     348
# ...

# %%
st_per.loc[(st_per.platform)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 st_per.loc[(st_per.platform)]
#
# File c:\Users\vasud\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\vasud\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
# ...

# %%
st_per.loc[(st_per.post_day=="Sunday")]
# Out:
#     post_id   platform post_type         post_time  likes  comments  shares  \
# 1         2   Facebook  carousel    5/14/2023 0:45   3660       432     324
# 6         7  Instagram     image   2/26/2023 11:45   1982        30     906
# 17       18    Twitter      text    7/23/2023 5:45    512       123     338
# 23       24  Instagram  carousel    1/1/2023 20:00   5000        80     399
# 30       31   Facebook      poll   9/10/2023 13:45   4795       449     978
# 38       39   Facebook     video     1/1/2023 6:00   5000       430     980
# 52       53    Twitter     video  11/12/2023 17:30   1498        46      96
# 58       59    Twitter     video   12/24/2023 7:45    344        99     194
# 60       61  Instagram     video  12/31/2023 22:30   3544       167     761
# 66       67   Facebook  carousel    4/23/2023 8:15   2026       390     165
# 79       80   Facebook      text   6/25/2023 15:15    553       320     312
# ...

# %%
st_per.loc[[1,6,9,34,56]]
# Out:
#     post_id   platform post_type        post_time  likes  comments  shares  \
# 1         2   Facebook  carousel   5/14/2023 0:45   3660       432     324
# 6         7  Instagram     image  2/26/2023 11:45   1982        30     906
# 9        10    Twitter  carousel  5/11/2023 11:00   1878       225     438
# 34       35  Instagram     image   6/6/2023 19:30   1309       201     852
# 56       57  Instagram     video   7/13/2023 9:15   4846       134     498
#
#     post_day sentiment_score
# 1     Sunday         neutral
# 6     Sunday        positive
# 9   Thursday         neutral
# 34   Tuesday        negative
# 56  Thursday         neutral

# %%
st_per.loc[[1,6,9,34,56],]

# %%
st_per.loc[(st_per['comments']>=500) &(st_per['post_type']=='video')]
# loc are used to filtreat our data
# Out:
#     post_id  platform post_type        post_time  likes  comments  shares  \
# 35       36  Facebook     video   4/8/2023 19:15   5000       500      43
# 74       75  Facebook     video  7/26/2023 20:15   5000       500     404
#
#      post_day sentiment_score
# 35   Saturday        positive
# 74  Wednesday        positive

# %%
st_per.loc[(st_per['post_day']=='Thursday')&(st_per['sentiment_score']=='positive')]
# Out:
#     post_id   platform post_type        post_time  likes  comments  shares  \
# 0         1   Facebook     image  8/17/2023 14:45   2121       474     628
# 11       12    Twitter     video   6/15/2023 3:15    304        42      89
# 19       20   Facebook     image   2/2/2023 16:00    455        86      79
# 33       34    Twitter      poll   2/9/2023 15:30   2253       162      28
# 77       78  Instagram      poll   1/19/2023 7:15   2990        30     365
# 91       92   Facebook     video  2/23/2023 17:15   1857       216     344
#
#     post_day sentiment_score
# 0   Thursday        positive
# 11  Thursday        positive
# 19  Thursday        positive
# 33  Thursday        positive
# 77  Thursday        positive
# 91  Thursday        positive

# %%
st_per.iloc[0:5,0:5]
# Out:
#    post_id   platform post_type        post_time  likes
# 0        1   Facebook     image  8/17/2023 14:45   2121
# 1        2   Facebook  carousel   5/14/2023 0:45   3660
# 2        3  Instagram      poll  2/21/2023 16:15   4955
# 3        4    Twitter     image  11/16/2023 0:45   1183
# 4        5    Twitter     video   5/23/2023 0:30   3499

# %%
st_per.iloc[0:5,0:5]
# Out:
#    post_id   platform post_type        post_time  likes
# 0        1   Facebook     image  8/17/2023 14:45   2121
# 1        2   Facebook  carousel   5/14/2023 0:45   3660
# 2        3  Instagram      poll  2/21/2023 16:15   4955
# 3        4    Twitter     image  11/16/2023 0:45   1183
# 4        5    Twitter     video   5/23/2023 0:30   3499

# %%
#short values

st_per.sort_values('shares',ascending=False,ignore_index=True)
# Out:
#     post_id   platform post_type        post_time  likes  comments  shares  \
# 0        47   Facebook      poll   8/8/2023 17:45   4726        44     993
# 1        39   Facebook     video    1/1/2023 6:00   5000       430     980
# 2        31   Facebook      poll  9/10/2023 13:45   4795       449     978
# 3        70   Facebook      text   6/12/2023 9:30   3094        86     965
# 4        60  Instagram  carousel   5/19/2023 4:30   4763       332     956
# ..      ...        ...       ...              ...    ...       ...     ...
# 95       98    Twitter      text    8/5/2023 8:45    229       179      38
# 96       34    Twitter      poll   2/9/2023 15:30   2253       162      28
# 97      100  Instagram     image   6/6/2023 21:00   4483       357      25
# 98       16    Twitter     image  2/10/2023 13:00   2348       154      18
# 99       48   Facebook     video   3/22/2023 3:15   5000       232      16
#
#      post_day sentiment_score
# 0     Tuesday        negative
# ...

# %%
st_per.rename(columns={"platform":'plat_form',"post_id":'id'})
# Out:
#      id  plat_form post_type         post_time  likes  comments  shares  \
# 0     1   Facebook     image   8/17/2023 14:45   2121       474     628
# 1     2   Facebook  carousel    5/14/2023 0:45   3660       432     324
# 2     3  Instagram      poll   2/21/2023 16:15   4955       408     688
# 3     4    Twitter     image   11/16/2023 0:45   1183        90     187
# 4     5    Twitter     video    5/23/2023 0:30   3499       247     286
# ..  ...        ...       ...               ...    ...       ...     ...
# 95   96  Instagram  carousel   7/12/2023 17:45     36       294     911
# 96   97    Twitter     video  10/27/2023 23:45    314       108     458
# 97   98    Twitter      text     8/5/2023 8:45    229       179      38
# 98   99  Instagram      poll  12/29/2023 12:15   5000       500     204
# 99  100  Instagram     image    6/6/2023 21:00   4483       357      25
#
#      post_day sentiment_score
# 0    Thursday        positive
# 1      Sunday         neutral
# ...

# %%
st_per.sort_values('post_day',ascending=True,ignore_index=True)
# Out:
#     post_id   platform post_type        post_time  likes  comments  shares  \
# 0        16    Twitter     image  2/10/2023 13:00   2348       154      18
# 1        30   Facebook  carousel    2/3/2023 0:30   4594       216     739
# 2        52    Twitter     image  7/14/2023 15:00    950       113     327
# 3        43    Twitter  carousel  3/31/2023 16:00   2586        97      85
# 4        40  Instagram  carousel   8/4/2023 12:45    447       333     845
# ..      ...        ...       ...              ...    ...       ...     ...
# 95       58   Facebook     video  12/27/2023 4:00   2204       116     728
# 96       75   Facebook     video  7/26/2023 20:15   5000       500     404
# 97       64  Instagram  carousel  4/19/2023 19:45    130       452     724
# 98       88   Facebook      text   5/3/2023 12:30   3404       244      67
# 99       50  Instagram      text   7/12/2023 0:00   1551       206     127
#
#      post_day sentiment_score
# 0      Friday         neutral
# ...
