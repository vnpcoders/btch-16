# %% [markdown]
# Pandas is a Python library used for working with data sets.
#
# It has functions for analyzing, cleaning, exploring, and manipulating data.
#
# The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
l1=['vasu','niranjan','nilash']

print(l1)
ser=pd.Series(l1)
print(ser)
# Out:
# ['vasu', 'niranjan', 'nilash']
# 0        vasu
# 1    niranjan
# 2      nilash
# dtype: object

# %%
l1=['vasu','niranjan','nilash','patidar']

print(l1)
index=['a','b','c','d']
ser=pd.Series(l1,index=index)
print(ser)
# Out:
# ['vasu', 'niranjan', 'nilash', 'patidar']
# a        vasu
# b    niranjan
# c      nilash
# d     patidar
# dtype: object

# %%
l1=([12,3,4,5])
print(l1)
index=['pen','pensil','rubar','dester']
ser=pd.Series(l1,index=index,dtype=float)
print(ser)
print(type(ser))
# Out:
# [12, 3, 4, 5]
# pen       12.0
# pensil     3.0
# rubar      4.0
# dester     5.0
# dtype: float64
# <class 'pandas.core.series.Series'>

# %%
l1=([12,3,4,5])
print(l1)
index=['pen','pensil','rubar','dester']
ser=pd.Series(l1,index=index,dtype=str)
print(ser)
print(type(ser))
print(len(ser))
# Out:
# [12, 3, 4, 5]
# pen       12
# pensil     3
# rubar      4
# dester     5
# dtype: object
# <class 'pandas.core.series.Series'>
# 4

# %%
#data frame
df={
    "Name":["vasu","niranjan","nilash","rekha","ram"],
    "Age":[23,24,22,26,30],
    "City":['dewas','indore','ujjan','bhopal','sighor']

}
print(df)
# Out:
# {'Name': ['vasu', 'niranjan', 'nilash', 'rekha', 'ram'], 'Age': [23, 24, 22, 26, 30], 'City': ['dewas', 'indore', 'ujjan', 'bhopal', 'sighor']}

# %%
dfd=pd.DataFrame(df,index=['A','B','C','D','E'])
print(dfd)
# Out:
#        Name  Age    City
# A      vasu   23   dewas
# B  niranjan   24  indore
# C    nilash   22   ujjan
# D     rekha   26  bhopal
# E       ram   30  sighor

# %%
df={
    "subject":["maths","physics","science","sst"],
    "teachername":["sukhi","vasudev","ram","sruti"],
    "piriat":[1,2,3,4]
}
print(df)
dfd=pd.DataFrame(df,index=['A','B','C','d'])
print(dfd)
# Out:
# {'subject': ['maths', 'physics', 'science', 'sst'], 'teachername': ['sukhi', 'vasudev', 'ram', 'sruti'], 'piriat': [1, 2, 3, 4]}
#    subject teachername  piriat
# A    maths       sukhi       1
# B  physics     vasudev       2
# C  science         ram       3
# d      sst       sruti       4

# %%
df={
    "student":["sukhi","vasudev","ram","sruti"],
    "persent":[67,102,34,56],
    "gread":["B","A++","fail","c"]
}
print(df)
dfd=pd.DataFrame(df,index=['A','B','C','d'])
print(dfd)
# Out:
# {'student': ['sukhi', 'vasudev', 'ram', 'sruti'], 'persent': [67, 102, 34, 56], 'gread': ['B', 'A++', 'fail', 'c']}
#    student  persent gread
# A    sukhi       67     B
# B  vasudev      102   A++
# C      ram       34  fail
# d    sruti       56     c

# %%
#data set loding

kl=pd.read_csv("social_media_engagement1.csv")
kl.head()
# Out:
#    post_id   platform post_type        post_time  likes  comments  shares  \
# 0        1   Facebook     image  8/17/2023 14:45   2121       474     628
# 1        2   Facebook  carousel   5/14/2023 0:45   3660       432     694
# 2        3  Instagram      poll  2/21/2023 16:15   4955       408     688
# 3        4    Twitter     image  11/16/2023 0:45   1183        90     187
# 4        5    Twitter     video   5/23/2023 0:30   3499       247     286
#
#    post_day sentiment_score
# 0  Thursday        positive
# 1    Sunday         neutral
# 2   Tuesday        negative
# 3  Thursday        negative
# 4   Tuesday        positive

# %%
kl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   post_id          100 non-null    int64
#  1   platform         100 non-null    object
#  2   post_type        100 non-null    object
#  3   post_time        100 non-null    object
#  4   likes            100 non-null    int64
#  5   comments         100 non-null    int64
#  6   shares           100 non-null    int64
#  7   post_day         100 non-null    object
#  8   sentiment_score  100 non-null    object
# dtypes: int64(4), object(5)
# memory usage: 7.2+ KB

# %%
ap=pd.read_csv("nursery.csv")
ap.head()
# Out:
#   parents has_nurs      form children     housing     finance         social  \
# 0   usual   proper  complete        1  convenient  convenient        nonprob
# 1   usual   proper  complete        1  convenient  convenient        nonprob
# 2   usual   proper  complete        1  convenient  convenient        nonprob
# 3   usual   proper  complete        1  convenient  convenient  slightly_prob
# 4   usual   proper  complete        1  convenient  convenient  slightly_prob
#
#         health final evaluation
# 0  recommended        recommend
# 1     priority         priority
# 2    not_recom        not_recom
# 3  recommended        recommend
# 4     priority         priority

# %%
ap=pd.read_csv("nursery.csv")
ap.tail()
# Out:
#           parents   has_nurs    form children   housing finance  \
# 12955  great_pret  very_crit  foster     more  critical  inconv
# 12956  great_pret  very_crit  foster     more  critical  inconv
# 12957  great_pret  very_crit  foster     more  critical  inconv
# 12958  great_pret  very_crit  foster     more  critical  inconv
# 12959  great_pret  very_crit  foster     more  critical  inconv
#
#               social       health final evaluation
# 12955  slightly_prob     priority       spec_prior
# 12956  slightly_prob    not_recom        not_recom
# 12957    problematic  recommended       spec_prior
# 12958    problematic     priority       spec_prior
# 12959    problematic    not_recom        not_recom

# %%
ap=pd.read_csv("nursery.csv")
ap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12960 entries, 0 to 12959
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   parents           12960 non-null  object
#  1   has_nurs          12960 non-null  object
#  2   form              12960 non-null  object
#  3   children          12960 non-null  object
#  4   housing           12960 non-null  object
#  5   finance           12960 non-null  object
#  6   social            12960 non-null  object
#  7   health            12960 non-null  object
#  8   final evaluation  12960 non-null  object
# dtypes: object(9)
# memory usage: 911.4+ KB

# %%
ap.shape
# Out:
# (12960, 9)

# %%
ap.describe()
# Out:
#        parents has_nurs      form children     housing     finance   social  \
# count    12960    12960     12960    12960       12960       12960    12960
# unique       3        5         4        4           3           2        3
# top      usual   proper  complete        1  convenient  convenient  nonprob
# freq      4320     2592      3240     3240        4320        6480     4320
#
#              health final evaluation
# count         12960            12960
# unique            3                5
# top     recommended        not_recom
# freq           4320             4320

# %%
pd.__version__
# Out:
# '2.3.1'

# %%
vp=pd.read_excel('bike_buyers.xlsx')
vp.head()
# Out:
#       ID Marital Status  Gender   Income  Children        Education  \
# 0  12496        Married  Female  40000.0       1.0        Bachelors
# 1  24107        Married    Male  30000.0       3.0  Partial College
# 2  14177        Married    Male  80000.0       5.0  Partial College
# 3  24381         Single     NaN  70000.0       0.0        Bachelors
# 4  25597         Single    Male  30000.0       0.0        Bachelors
#
#        Occupation Home Owner  Cars Commute Distance   Region   Age  \
# 0  Skilled Manual        Yes   0.0        0-1 Miles   Europe  42.0
# 1        Clerical        Yes   1.0        0-1 Miles   Europe  43.0
# 2    Professional         No   2.0        2-5 Miles   Europe  60.0
# 3    Professional        Yes   1.0       5-10 Miles  Pacific  41.0
# 4        Clerical         No   0.0        0-1 Miles   Europe  36.0
#
#   Purchased Bike
# 0             No
# 1             No
# 2             No
# 3            Yes
# 4            Yes

# %%
vp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                1000 non-null   int64
#  1   Marital Status    993 non-null    object
#  2   Gender            989 non-null    object
#  3   Income            994 non-null    float64
#  4   Children          992 non-null    float64
#  5   Education         1000 non-null   object
#  6   Occupation        1000 non-null   object
#  7   Home Owner        996 non-null    object
#  8   Cars              991 non-null    float64
#  9   Commute Distance  1000 non-null   object
#  10  Region            1000 non-null   object
#  11  Age               992 non-null    float64
#  12  Purchased Bike    1000 non-null   object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 101.7+ KB

# %%
vp.describe()
# Out:
#                  ID         Income    Children        Cars         Age
# count   1000.000000     994.000000  992.000000  991.000000  992.000000
# mean   19965.992000   56267.605634    1.910282    1.455096   44.181452
# std     5347.333948   31067.817462    1.626910    1.121755   11.362007
# min    11000.000000   10000.000000    0.000000    0.000000   25.000000
# 25%    15290.750000   30000.000000    0.000000    1.000000   35.000000
# 50%    19744.000000   60000.000000    2.000000    1.000000   43.000000
# 75%    24470.750000   70000.000000    3.000000    2.000000   52.000000
# max    29447.000000  170000.000000    5.000000    4.000000   89.000000

# %%
vp.isnull().sum()
# Out:
# ID                   0
# Marital Status       7
# Gender              11
# Income               6
# Children             8
# Education            0
# Occupation           0
# Home Owner           4
# Cars                 9
# Commute Distance     0
# Region               0
# Age                  8
# Purchased Bike       0
# dtype: int64

# %%
#data visualization

import matplotlib.pyplot as plt
plt.figure(figsize=(12,4))
plt.plot(vp["ID"])
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10,3))
sns.histplot(vp["Income"])
# Out:
# <Axes: xlabel='Income', ylabel='Count'>

# %%
plt.figure(figsize=(10,3))
sns.
# Out:
#   Cell In[28], line 2
#     sns.
#         ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(5,4))
plt.scatter(x=kl['likes'],y=kl['comments'])
plt.title("data scatterdness")
plt.xlabel("like")
plt.ylabel("comments")
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x=kl['likes'],y=kl['comments'],hue=kl["post_type"])
plt.title("data scatterdness")
plt.xlabel("like")
plt.ylabel("comments")
plt.show()

# %%
plt.plot(kl['likes'],'d-.r',ms = 10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# sns.barplot(x="post_type",
#             y="likes",
#             data=kl,
#             hue="platform")
# plt.title("BAR chat")
# plt.legend()
# plt.show()

# %%
plt.pie

# %%
kl["post_type"].value_counts()
# Out:
# post_type
# carousel    26
# video       23
# text        21
# image       17
# poll        13
# Name: count, dtype: int64

# %%
kl["post_type"].value_counts().sum()
# Out:
# np.int64(100)

# %%
kl["post_day"].value_counts().values
# Out:
# array([18, 16, 16, 15, 14, 11, 10])

# %%
kl["post_day"].value_counts().index
# Out:
# Index(['Wednesday', 'Friday', 'Thursday', 'Tuesday', 'Sunday', 'Monday',
#        'Saturday'],
#       dtype='object', name='post_day')

# %%
kl["post_day"].value_counts().sum()
# Out:
# np.int64(100)

# %%
plt.pie(kl['post_day'].value_counts().values ,
        labels=kl['post_day'].value_counts().index,
        autopct="%0.2f%%",
        startangle=90)
plt.show()

# %%
plt.pie(kl['post_day'].value_counts().values ,
        labels=kl['post_day'].value_counts().index,
        autopct="%0.2f%%",
        startangle=90,
        wedgeprops={'width':0.35,"linewidth":6,'edgecolor':'white'})
plt.show()

# %%
sns .countplot(kl['post_day'])
plt.show()

# %%
sns.pairplot(data=kl,)

# %%
sns.pairplot(data=kl,hue="post_type")

# %%
sns.pairplot(data=kl,kind="hist",hue="post_type")

# %%
sns.pairplot(data=kl,kind="kde",hue="post_type")

# %%
corr=kl.select_dtypes(include="number")
sns.heatmap(data=corr.corr(),annot=True,cmap="Accent")
plt.show()

# %%
from zipfile import ZipFile
with ZipFile('student.zip','r')as file:
    file.extractall("student")

# %%
from seaborn import load_dataset

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
a=load_dataset("tips")
print(a)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(a["day"])
# Out:
# <Axes: xlabel='day', ylabel='Count'>

# %%
import seaborn as sns
plt.figure(figsize=(10,3))

sns.barplot(a["time"])
# Out:
# <Axes: ylabel='time'>

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x=a['smoker'],y=a['day'],hue=a["sex"])
plt.title("data scatterdness")
plt.xlabel("tip")
plt.ylabel("day")
plt.show()

# %%
plt.pie(a['day'].value_counts().values ,
        labels=a['day'].value_counts().index,
        autopct="%0.2f%%",
        startangle=90)
plt.show()

# %%
corr=a.select_dtypes(include="number")
sns.heatmap(data=corr.corr(),annot=True,cmap="Accent")
plt.show()

# %%
sns.countplot(a['sex'])
plt.show()

# %%
plt.plot(a['day'])
plt.show()

# %%
a.value_counts()
# Out:
# total_bill  tip    sex     smoker  day   time    size
# 13.00       2.00   Female  Yes     Thur  Lunch   2       2
# 5.75        1.00   Female  Yes     Fri   Dinner  2       1
# 3.07        1.00   Female  Yes     Sat   Dinner  1       1
# 7.25        5.15   Male    Yes     Sun   Dinner  2       1
# 7.51        2.00   Male    No      Thur  Lunch   2       1
#                                                         ..
# 45.35       3.50   Male    Yes     Sun   Dinner  3       1
# 48.17       5.00   Male    No      Sun   Dinner  6       1
# 48.27       6.73   Male    No      Sat   Dinner  4       1
# 48.33       9.00   Male    No      Sat   Dinner  4       1
# 50.81       10.00  Male    Yes     Sat   Dinner  3       1
# Name: count, Length: 243, dtype: int64

# %%
a.sex.value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
sns.countplot(a["sex"])
plt.figure(figsize=(10,5))
plt.show()

# %%
a['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
import numpy as np


dict={
    "Name":['vasu','dev','niranjan',None,'nilesh','sukhi','ritek','god'],
    "age":[ np.nan,23,34,66,22,33,24,None],
    'location':['dewas','indore','ujjain','dewas',None,'indore','ujjain','dewas'],
    'Weight':[45.3,np.nan,76,75,None,34.76,87.3,75]

}
df=pd.DataFrame(dict)
df
# Out:
#        Name   age location  Weight
# 0      vasu   NaN    dewas   45.30
# 1       dev  23.0   indore     NaN
# 2  niranjan  34.0   ujjain   76.00
# 3      None  66.0    dewas   75.00
# 4    nilesh  22.0     None     NaN
# 5     sukhi  33.0   indore   34.76
# 6     ritek  24.0   ujjain   87.30
# 7       god   NaN    dewas   75.00

# %%
df.to_csv("D:\\btch 16\\panda\\hyygrow.csv")

# %%
drf=pd.read_csv("hyygrow.csv",index_col="location")
drf
# Out:
#           Unnamed: 0      Name   age  Weight
# location
# dewas              0      vasu   NaN   45.30
# indore             1       dev  23.0     NaN
# ujjain             2  niranjan  34.0   76.00
# dewas              3       NaN  66.0   75.00
# NaN                4    nilesh  22.0     NaN
# indore             5     sukhi  33.0   34.76
# ujjain             6     ritek  24.0   87.30
# dewas              7       god   NaN   75.00

# %%
drf=pd.read_csv("hyygrow.csv")
new_df=drf.dropna()
print(new_df)
# Out:
#    Unnamed: 0      Name   age location  Weight
# 2           2  niranjan  34.0   ujjain   76.00
# 5           5     sukhi  33.0   indore   34.76
# 6           6     ritek  24.0   ujjain   87.30

# %%
drf=pd.read_csv("hyygrow.csv")
new_df=drf.drop('Unnamed: 0',axis=1)

# %%
drf=pd.read_csv("hyygrow.csv")
drf
# Out:
#    Unnamed: 0      Name   age location  Weight
# 0           0      vasu   NaN    dewas   45.30
# 1           1       dev  23.0   indore     NaN
# 2           2  niranjan  34.0   ujjain   76.00
# 3           3       NaN  66.0    dewas   75.00
# 4           4    nilesh  22.0      NaN     NaN
# 5           5     sukhi  33.0   indore   34.76
# 6           6     ritek  24.0   ujjain   87.30
# 7           7       god   NaN    dewas   75.00

# %%
#fillna
fill=drf.fillna(0)
fill
# Out:
#    Unnamed: 0      Name   age location  Weight
# 0           0      vasu   0.0    dewas   45.30
# 1           1       dev  23.0   indore    0.00
# 2           2  niranjan  34.0   ujjain   76.00
# 3           3         0  66.0    dewas   75.00
# 4           4    nilesh  22.0        0    0.00
# 5           5     sukhi  33.0   indore   34.76
# 6           6     ritek  24.0   ujjain   87.30
# 7           7       god   0.0    dewas   75.00

# %%
hyy=drf
hyy["Name"].fillna("narayan",inplace=True)
hyy
# Out:
#    Unnamed: 0      Name   age location  Weight
# 0           0      vasu   NaN    dewas   45.30
# 1           1       dev  23.0   indore     NaN
# 2           2  niranjan  34.0   ujjain   76.00
# 3           3   narayan  66.0    dewas   75.00
# 4           4    nilesh  22.0      NaN     NaN
# 5           5     sukhi  33.0   indore   34.76
# 6           6     ritek  24.0   ujjain   87.30
# 7           7       god   NaN    dewas   75.00

# %%
hyy["Weight"].fillna(hyy['Weight'].mean(),inplace=True)
hyy["age"].fillna(hyy['age'].mean(),inplace=True)
hyy
# Out:
#    Unnamed: 0      Name        age location  Weight
# 0           0      vasu  33.666667    dewas   45.30
# 1           1       dev  23.000000   indore   65.56
# 2           2  niranjan  34.000000   ujjain   76.00
# 3           3   narayan  66.000000    dewas   75.00
# 4           4    nilesh  22.000000      NaN   65.56
# 5           5     sukhi  33.000000   indore   34.76
# 6           6     ritek  24.000000   ujjain   87.30
# 7           7       god  33.666667    dewas   75.00

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
hyy["location"].mode()[0]
# Out:
# 0    dewas
# Name: location, dtype: object

# %%
hyy['location'].fillna(hyy["location"].mode()[0],inplace=True)
hyy
# Out:
#    Unnamed: 0      Name        age location  Weight
# 0           0      vasu  33.666667    dewas   45.30
# 1           1       dev  23.000000   indore   65.56
# 2           2  niranjan  34.000000   ujjain   76.00
# 3           3   narayan  66.000000    dewas   75.00
# 4           4    nilesh  22.000000    dewas   65.56
# 5           5     sukhi  33.000000   indore   34.76
# 6           6     ritek  24.000000   ujjain   87.30
# 7           7       god  33.666667    dewas   75.00

# %%
hyy.isnull().sum()
# Out:
# Unnamed: 0    0
# Name          0
# age           0
# location      0
# Weight        0
# dtype: int64

# %%
hyy.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
hyy.drop_duplicates(inplace=True)

# %%
sc=pd.read_excel("bike_buyers.xlsx")
sc.isnull().sum()
sc
# Out:
#         ID Marital Status  Gender    Income  Children        Education  \
# 0    12496        Married  Female   40000.0       1.0        Bachelors
# 1    24107        Married    Male   30000.0       3.0  Partial College
# 2    14177        Married    Male   80000.0       5.0  Partial College
# 3    24381         Single     NaN   70000.0       0.0        Bachelors
# 4    25597         Single    Male   30000.0       0.0        Bachelors
# ..     ...            ...     ...       ...       ...              ...
# 995  23731        Married    Male   60000.0       2.0      High School
# 996  28672         Single    Male   70000.0       4.0  Graduate Degree
# 997  11809        Married     NaN   60000.0       2.0        Bachelors
# 998  19664         Single    Male  100000.0       3.0        Bachelors
# 999  12121         Single    Male   60000.0       3.0      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region   Age  \
# ...

# %%
sc.isnull().sum()
# Out:
# ID                   0
# Marital Status       0
# Gender              11
# Income               6
# Children             8
# Education            0
# Occupation           0
# Home Owner           4
# Cars                 9
# Commute Distance     0
# Region               0
# Age                  8
# Purchased Bike       0
# dtype: int64

# %%
com=["Gender","Home Owner"]
for i in com:
    sc[i].fillna(sc[i].mode()[0],inplace=True)

# %%
sc.isnull().sum()
# Out:
# ID                  0
# Marital Status      0
# Gender              0
# Income              6
# Children            8
# Education           0
# Occupation          0
# Home Owner          0
# Cars                9
# Commute Distance    0
# Region              0
# Age                 8
# Purchased Bike      0
# dtype: int64

# %%
com=["Income","Children","Cars","Age"]
for i in com:
    sc[i].fillna(sc[i].mean(),inplace=True)

# %%
sc['Marital Status'].fillna(sc['Marital Status'].mode()[0],inplace=True)

# %%
sc.duplicated().sum()
# Out:
# np.int64(0)

# %%
sc['Gender'].mode()[0]
# Out:
# 'Male'

# %%
sc["Gender"].fillna

# %%
sc=pd.read_csv("social_media_engagement1.csv")
sc.isnull().sum()
# Out:
# post_id            0
# platform           0
# post_type          0
# post_time          0
# likes              0
# comments           0
# shares             0
# post_day           0
# sentiment_score    0
# dtype: int64

# %%
car=pd.read_csv('CarPrice_Assignment.csv')
print(car.to_string())
# Out:
#      car_ID  symboling                          CarName fueltype aspiration doornumber      carbody drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  curbweight enginetype cylindernumber  enginesize fuelsystem  boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  highwaympg      price
# 0         1          3               alfa-romero giulia      gas        std        two  convertible        rwd          front       88.6      168.8      64.1       48.8        2548       dohc           four         130       mpfi       3.47   2.680              9.00         111     5000       21          27  13495.000
# 1         2          3              alfa-romero stelvio      gas        std        two  convertible        rwd          front       88.6      168.8      64.1       48.8        2548       dohc           four         130       mpfi       3.47   2.680              9.00         111     5000       21          27  16500.000
# ...

# %%
car.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
car["CarName"] = car["CarName"].str.split(n=1).str[0]

# %%
car["Model"] = car["CarName"].str.split(n=1).str[1]
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
car["Model"]=car["Model"].str.replace(" ",'')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 car["Model"]=car["Model"].str.replace(" ",'')
#
# NameError: name 'car' is not defined

# %%
car
# Out:
#      car_ID  symboling      CarName fueltype aspiration doornumber  \
# 0         1          3  alfa-romero      gas        std        two
# 1         2          3  alfa-romero      gas        std        two
# 2         3          1  alfa-romero      gas        std        two
# 3         4          2         audi      gas        std       four
# 4         5          2         audi      gas        std       four
# ..      ...        ...          ...      ...        ...        ...
# 200     201         -1        volvo      gas        std       four
# 201     202         -1        volvo      gas      turbo       four
# 202     203         -1        volvo      gas        std       four
# 203     204         -1        volvo   diesel      turbo       four
# 204     205         -1        volvo      gas      turbo       four
#
#          carbody drivewheel enginelocation  wheelbase  ...  fuelsystem  \
# 0    convertible        rwd          front       88.6  ...        mpfi
# ...

# %%
print(car.to_string())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print(car.to_string())
#
# NameError: name 'car' is not defined

# %%
car.duplicated().sum()
# Out:
# np.int64(0)

# %%
car.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# Model               2
# dtype: int64

# %%
bk=pd.read_excel("D:\\btch 16\\panda\\bike_buyers.xlsx")
bk
# Out:
#         ID Marital Status  Gender    Income  Children        Education  \
# 0    12496        Married  Female   40000.0       1.0        Bachelors
# 1    24107        Married    Male   30000.0       3.0  Partial College
# 2    14177        Married    Male   80000.0       5.0  Partial College
# 3    24381         Single     NaN   70000.0       0.0        Bachelors
# 4    25597         Single    Male   30000.0       0.0        Bachelors
# ..     ...            ...     ...       ...       ...              ...
# 995  23731        Married    Male   60000.0       2.0      High School
# 996  28672         Single    Male   70000.0       4.0  Graduate Degree
# 997  11809        Married     NaN   60000.0       2.0        Bachelors
# 998  19664         Single    Male  100000.0       3.0        Bachelors
# 999  12121         Single    Male   60000.0       3.0      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region   Age  \
# ...

# %%
bk.isnull().sum()
# Out:
# ID                   0
# Marital Status       7
# Gender              11
# Income               6
# Children             8
# Education            0
# Occupation           0
# Home Owner           4
# Cars                 9
# Commute Distance     0
# Region               0
# Age                  8
# Purchased Bike       0
# dtype: int64

# %%
bk["Marital Status"]=bk["Marital Status"].fillna("singal")

# %%
bk.isnull().sum()
# Out:
# ID                   0
# Marital Status       0
# Gender              11
# Income               6
# Children             8
# Education            0
# Occupation           0
# Home Owner           4
# Cars                 9
# Commute Distance     0
# Region               0
# Age                  8
# Purchased Bike       0
# dtype: int64

# %%
bk=bk.dropna()

# %%
bk.isnull().sum()
# Out:
# ID                  0
# Marital Status      0
# Gender              0
# Income              0
# Children            0
# Education           0
# Occupation          0
# Home Owner          0
# Cars                0
# Commute Distance    0
# Region              0
# Age                 0
# Purchased Bike      0
# dtype: int64
