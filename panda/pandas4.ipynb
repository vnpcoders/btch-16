# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
mae=pd.read_csv("social_media_engagement1.csv")

# %%
mae
# Out:
#     post_id   platform post_type         post_time  likes  comments  shares  \
# 0         1   Facebook     image   8/17/2023 14:45   2121       474     628
# 1         2   Facebook  carousel    5/14/2023 0:45   3660       432     694
# 2         3  Instagram      poll   2/21/2023 16:15   4955       408     688
# 3         4    Twitter     image   11/16/2023 0:45   1183        90     187
# 4         5    Twitter     video    5/23/2023 0:30   3499       247     286
# ..      ...        ...       ...               ...    ...       ...     ...
# 95       96  Instagram  carousel   7/12/2023 17:45     36       294     911
# 96       97    Twitter     video  10/27/2023 23:45    314       108     458
# 97       98    Twitter      text     8/5/2023 8:45    229       179      38
# 98       99  Instagram      poll  12/29/2023 12:15   5000       500     204
# 99      100  Instagram     image    6/6/2023 21:00   4483       357      25
#
#      post_day sentiment_score
# ...

# %%
mae.plot(y="likes",x="platform",figsize=(8,2),c="red")
# Out:
# <Axes: xlabel='platform'>

# %%
mae.plot(x="platform",y= ["likes","comments",'shares'],figsize=(8,2))
# Out:
# <Axes: xlabel='platform'>

# %%
mae.plot(x="platform",y= ["likes","comments",'shares'],kind='area',figsize=(8,2))
# Out:
# <Axes: xlabel='platform'>

# %% [markdown]
# mae.plot(y='likes',kind='hist',
#          figsize=(5,2))

# %%
mae.plot(x='likes',y='comm')
# Out:
# <Axes: ylabel='platform'>

# %%
#gropby

mae.head()
# Out:
#    post_id   platform post_type        post_time  likes  comments  shares  \
# 0        1   Facebook     image  8/17/2023 14:45   2121       474     628
# 1        2   Facebook  carousel   5/14/2023 0:45   3660       432     694
# 2        3  Instagram      poll  2/21/2023 16:15   4955       408     688
# 3        4    Twitter     image  11/16/2023 0:45   1183        90     187
# 4        5    Twitter     video   5/23/2023 0:30   3499       247     286
#
#    post_day sentiment_score
# 0  Thursday        positive
# 1    Sunday         neutral
# 2   Tuesday        negative
# 3  Thursday        negative
# 4   Tuesday        positive

# %%
mae.groupby('platform')

# %%
mae.groupby('platform')['likes'].agg('mean')
# Out:
# platform
# Facebook     2699.750000
# Instagram    2999.833333
# Twitter      1368.593750
# Name: likes, dtype: float64

# %%
mae.groupby('post_day')['comments'].agg('mean')
# Out:
# post_day
# Friday       232.312500
# Monday       154.454545
# Saturday     180.000000
# Sunday       244.357143
# Thursday     176.562500
# Tuesday      185.933333
# Wednesday    223.055556
# Name: comments, dtype: float64

# %%
mae.groupby('post_day')[['likes','comments']].agg('sum')
# Out:
#            likes  comments
# post_day
# Friday     42489      3717
# Monday     18326      1699
# Saturday   19994      1800
# Sunday     37716      3421
# Thursday   37591      2825
# Tuesday    35344      2789
# Wednesday  46721      4015

# %%
mae.groupby(["sentiment_score",'post_day'])[['likes','comments']].agg('sum')
# Out:
#                            likes  comments
# sentiment_score post_day
# negative        Friday      9591      1006
#                 Monday      6495       276
#                 Saturday    4890       591
#                 Sunday     19167      1861
#                 Thursday   11923       948
#                 Tuesday    12193       916
#                 Wednesday  11551       611
# neutral         Friday      4608       705
#                 Monday      4942       627
#                 Saturday    1461       134
#                 Sunday      9516      1084
#                 Thursday   15688       867
#                 Tuesday     5374       812
#                 Wednesday   7059      1101
# positive        Friday     28290      2006
#                 Monday      6889       796
#                 Saturday   13643      1075
#                 Sunday      9033       476
#                 Thursday    9980      1010
#                 Tuesday    17777      1061
# ...

# %%
mae.groupby(["sentiment_score",'post_day'])[['likes','comments']].agg(['sum','count',"mean"])
# Out:
#                            likes                    comments
#                              sum count         mean      sum count        mean
# sentiment_score post_day
# negative        Friday      9591     4  2397.750000     1006     4  251.500000
#                 Monday      6495     2  3247.500000      276     2  138.000000
#                 Saturday    4890     3  1630.000000      591     3  197.000000
#                 Sunday     19167     6  3194.500000     1861     6  310.166667
#                 Thursday   11923     5  2384.600000      948     5  189.600000
#                 Tuesday    12193     4  3048.250000      916     4  229.000000
#                 Wednesday  11551     3  3850.333333      611     3  203.666667
# neutral         Friday      4608     4  1152.000000      705     4  176.250000
#                 Monday      4942     4  1235.500000      627     4  156.750000
#                 Saturday    1461     2   730.500000      134     2   67.000000
# ...

# %%
mae.groupby("sentiment_score")['likes'].plot.bar()
# Out:
# sentiment_score
# negative    Axes(0.125,0.11;0.775x0.77)
# neutral     Axes(0.125,0.11;0.775x0.77)
# positive    Axes(0.125,0.11;0.775x0.77)
# Name: likes, dtype: object

# %%
mae.groupby("sentiment_score")['likes'].agg('mean').plot(kind='bar',figsize=(4,2))
# Out:
# <Axes: xlabel='sentiment_score'>

# %%
mae.groupby("sentiment_score")['likes'].agg('mean').plot(kind='pie',figsize=(4,2),autopct='%0.2f%%')
# Out:
# <Axes: ylabel='likes'>

# %%
sns.barplot(x="sentiment_score",
            y='likes',
            hue='platform',
            data=mae,
            errorbar=None)
# Out:
# <Axes: xlabel='sentiment_score', ylabel='likes'>

# %%
#join or marge

data1 = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
         'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],})

data2 =pd.DataFrame( {'key': ['K0', 'K1', 'K2', 'K3'],
         'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']})
data3 =pd.DataFrame( {'key': ['K0', 'K1', 'K2', 'K3'],
         'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']})

# %%
dc=pd.concat((data1,data2,data3),axis=1)
dc
# Out:
#   key    Name  Age key    Address Qualification key    Address Qualification
# 0  K0     Jai   27  K0     Nagpur         Btech  K0     Nagpur         Btech
# 1  K1  Princi   24  K1     Kanpur           B.A  K1     Kanpur           B.A
# 2  K2  Gaurav   22  K2  Allahabad          Bcom  K2  Allahabad          Bcom
# 3  K3    Anuj   32  K3    Kannuaj        B.hons  K3    Kannuaj        B.hons

# %%
dc=pd.concat((data1,data2,data3),axis=0,ignore_index=True)
dc
# Out:
#    key    Name   Age    Address Qualification
# 0   K0     Jai  27.0        NaN           NaN
# 1   K1  Princi  24.0        NaN           NaN
# 2   K2  Gaurav  22.0        NaN           NaN
# 3   K3    Anuj  32.0        NaN           NaN
# 4   K0     NaN   NaN     Nagpur         Btech
# 5   K1     NaN   NaN     Kanpur           B.A
# 6   K2     NaN   NaN  Allahabad          Bcom
# 7   K3     NaN   NaN    Kannuaj        B.hons
# 8   K0     NaN   NaN     Nagpur         Btech
# 9   K1     NaN   NaN     Kanpur           B.A
# 10  K2     NaN   NaN  Allahabad          Bcom
# 11  K3     NaN   NaN    Kannuaj        B.hons

# %%
#join or marge

data1 = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3',"k4"],
         'Name':['Jai', 'Princi', 'Gaurav', 'Anuj',"vasu"],
        'Age':[27, 24, 22, 32,23],})

data2 =pd.DataFrame( {'key': ['K0', 'K1', 'K2', 'K3',"k5"],
         'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',"dewas"],
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons',"btech"]})

# %%
merge=data1.merge(data2,on=['key'])
merge
# Out:
#   key    Name  Age    Address Qualification
# 0  K0     Jai   27     Nagpur         Btech
# 1  K1  Princi   24     Kanpur           B.A
# 2  K2  Gaurav   22  Allahabad          Bcom
# 3  K3    Anuj   32    Kannuaj        B.hons

# %%
merge_outer=data1.merge(data2,on=['key'],how="outer")
merge_outer
# Out:
#   key    Name   Age    Address Qualification
# 0  K0     Jai  27.0     Nagpur         Btech
# 1  K1  Princi  24.0     Kanpur           B.A
# 2  K2  Gaurav  22.0  Allahabad          Bcom
# 3  K3    Anuj  32.0    Kannuaj        B.hons
# 4  k4    vasu  23.0        NaN           NaN
# 5  k5     NaN   NaN      dewas         btech

# %%
merge_inner=data1.merge(data2,on=['key'],how="inner")
merge_inner
# Out:
#   key    Name  Age    Address Qualification
# 0  K0     Jai   27     Nagpur         Btech
# 1  K1  Princi   24     Kanpur           B.A
# 2  K2  Gaurav   22  Allahabad          Bcom
# 3  K3    Anuj   32    Kannuaj        B.hons

# %%
merge_right=data1.merge(data2,on=['key'],how="right")
merge_right
# Out:
#   key    Name   Age    Address Qualification
# 0  K0     Jai  27.0     Nagpur         Btech
# 1  K1  Princi  24.0     Kanpur           B.A
# 2  K2  Gaurav  22.0  Allahabad          Bcom
# 3  K3    Anuj  32.0    Kannuaj        B.hons
# 4  k5     NaN   NaN      dewas         btech

# %%
merge_left=data1.merge(data2,on=['key'],how="left")
merge_left
# Out:
#   key    Name  Age    Address Qualification
# 0  K0     Jai   27     Nagpur         Btech
# 1  K1  Princi   24     Kanpur           B.A
# 2  K2  Gaurav   22  Allahabad          Bcom
# 3  K3    Anuj   32    Kannuaj        B.hons
# 4  k4    vasu   23        NaN           NaN

# %%
merge_cross=pd.merge(data1,data2,how="cross")
merge_cross
# Out:
#    key_x    Name  Age key_y    Address Qualification
# 0     K0     Jai   27    K0     Nagpur         Btech
# 1     K0     Jai   27    K1     Kanpur           B.A
# 2     K0     Jai   27    K2  Allahabad          Bcom
# 3     K0     Jai   27    K3    Kannuaj        B.hons
# 4     K0     Jai   27    k5      dewas         btech
# 5     K1  Princi   24    K0     Nagpur         Btech
# 6     K1  Princi   24    K1     Kanpur           B.A
# 7     K1  Princi   24    K2  Allahabad          Bcom
# 8     K1  Princi   24    K3    Kannuaj        B.hons
# 9     K1  Princi   24    k5      dewas         btech
# 10    K2  Gaurav   22    K0     Nagpur         Btech
# 11    K2  Gaurav   22    K1     Kanpur           B.A
# 12    K2  Gaurav   22    K2  Allahabad          Bcom
# 13    K2  Gaurav   22    K3    Kannuaj        B.hons
# 14    K2  Gaurav   22    k5      dewas         btech
# 15    K3    Anuj   32    K0     Nagpur         Btech
# 16    K3    Anuj   32    K1     Kanpur           B.A
# ...

# %%
merge_cross=pd.merge(data1,data2,how="outer",on='key',validate='one_to_one')
merge_cross
# Out:
#   key    Name   Age    Address Qualification
# 0  K0     Jai  27.0     Nagpur         Btech
# 1  K1  Princi  24.0     Kanpur           B.A
# 2  K2  Gaurav  22.0  Allahabad          Bcom
# 3  K3    Anuj  32.0    Kannuaj        B.hons
# 4  k4    vasu  23.0        NaN           NaN
# 5  k5     NaN   NaN      dewas         btech

# %%
merge_cross=pd.merge(data1,data2,how="outer",on='key',validate='one_to_many')
merge_cross
# Out:
#   key    Name   Age    Address Qualification
# 0  K0     Jai  27.0     Nagpur         Btech
# 1  K1  Princi  24.0     Kanpur           B.A
# 2  K2  Gaurav  22.0  Allahabad          Bcom
# 3  K3    Anuj  32.0    Kannuaj        B.hons
# 4  k4    vasu  23.0        NaN           NaN
# 5  k5     NaN   NaN      dewas         btech

# %%
merge_cross=pd.merge(data1,data2,how="outer",on='key',validate='many_to_many')
merge_cross
# Out:
#   key    Name   Age    Address Qualification
# 0  K0     Jai  27.0     Nagpur         Btech
# 1  K1  Princi  24.0     Kanpur           B.A
# 2  K2  Gaurav  22.0  Allahabad          Bcom
# 3  K3    Anuj  32.0    Kannuaj        B.hons
# 4  k4    vasu  23.0        NaN           NaN
# 5  k5     NaN   NaN      dewas         btech

# %%
st=pd.read_csv('D:\\btch 16\\panda\\student\\student-por.csv',sep=";")
st
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
pd.pivot_table(st,values="health",index='sex',columns='Fjob')
# Out:
# Fjob   at_home    health     other  services   teacher
# sex
# F     3.172414  3.928571  3.400901  3.260000  3.444444
# M     3.538462  4.777778  3.896552  3.481481  3.833333

# %%
pd.pivot_table(st,values="health",index='sex',columns='Fjob',aggfunc='sum')
# Out:
# Fjob  at_home  health  other  services  teacher
# sex
# F          92      55    755       326       62
# M          46      43    565       282       69

# %%
pd.pivot_table(st,values="health",index='sex',columns='Fjob',aggfunc='mean')
# Out:
# Fjob   at_home    health     other  services   teacher
# sex
# F     3.172414  3.928571  3.400901  3.260000  3.444444
# M     3.538462  4.777778  3.896552  3.481481  3.833333

# %%
pd.pivot_table(st,values="health",
               index=['sex','address'],
               columns='Fjob',
               aggfunc='median')
# Out:
# Fjob         at_home  health  other  services  teacher
# sex address
# F   R            2.5     5.0    4.0       3.0      4.5
#     U            3.0     4.0    4.0       3.0      3.0
# M   R            4.0     5.0    4.0       4.0      5.0
#     U            4.5     5.0    5.0       3.0      4.0

# %%
pd.pivot_table(st,values="health",
               index=['sex','address'],
               columns=['Fedu','Fjob'],
               aggfunc='median')
# Out:
# Fedu              0             1                              2               \
# Fjob        at_home other at_home other services teacher at_home health other
# sex address
# F   R           NaN   5.0     2.0   3.0      2.5     NaN     NaN    NaN   4.0
#     U           NaN   4.5     3.0   4.0      3.0     3.0     3.0    5.0   3.0
# M   R           4.0   NaN     2.0   4.5      3.0     NaN     3.0    NaN   4.5
#     U           NaN   3.0     5.0   5.0      3.5     NaN     4.0    4.5   5.0
#
# Fedu                       3                                     4         \
# Fjob        services at_home health other services teacher at_home health
# sex address
# F   R            3.0     NaN    NaN   3.5      2.5     NaN     5.0    5.0
#     U            3.5     3.0    4.0   3.0      3.0     3.0     3.0    4.0
# M   R            3.5     5.0    NaN   3.0      4.5     NaN     NaN    5.0
#     U            3.0     4.0    4.0   3.0      3.0     NaN     NaN    5.0
#
# Fedu
# ...

# %%
pd.pivot_table(st,values="health",
               index=['sex','address'],
               columns=['Fedu','Fjob'],
               aggfunc=['median','sum'])
# Out:
#              median                                                            \
# Fedu              0             1                              2
# Fjob        at_home other at_home other services teacher at_home health other
# sex address
# F   R           NaN   5.0     2.0   3.0      2.5     NaN     NaN    NaN   4.0
#     U           NaN   4.5     3.0   4.0      3.0     3.0     3.0    5.0   3.0
# M   R           4.0   NaN     2.0   4.5      3.0     NaN     3.0    NaN   4.5
#     U           NaN   3.0     5.0   5.0      3.5     NaN     4.0    4.5   5.0
#
#                       ...     sum                                         \
# Fedu                  ...       3                                      4
# Fjob        services  ... at_home health  other services teacher at_home
# sex address           ...
# F   R            3.0  ...     NaN    NaN   20.0     17.0     NaN     5.0
#     U            3.5  ...     3.0    8.0  118.0     60.0     3.0     6.0
# ...

# %%
table=pd.pivot_table(st,values="health",
               index=['sex','address'],
               columns=['Fedu','Fjob'],
               aggfunc=['median','sum'])
