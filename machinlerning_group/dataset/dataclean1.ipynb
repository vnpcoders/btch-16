# %%
import numpy as np
import pandas as pd
import matplotlib

# %%
df=pd.read_csv('retail_store_sales.csv')

# %%
df
# Out:
#       Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0        TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1        TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2        TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3        TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4        TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
# ...              ...         ...            ...           ...             ...
# 12570    TXN_9347481     CUST_18     Patisserie   Item_23_PAT            38.0
# 12571    TXN_4009414     CUST_03      Beverages    Item_2_BEV             6.5
# 12572    TXN_5306010     CUST_11       Butchers    Item_7_BUT            14.0
# 12573    TXN_5167298     CUST_04      Furniture    Item_7_FUR            14.0
# 12574    TXN_2407494     CUST_23           Food   Item_9_FOOD            17.0
#
# ...

# %%
df
# Out:
#       Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0        TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1        TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2        TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3        TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4        TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
# ...              ...         ...            ...           ...             ...
# 12570    TXN_9347481     CUST_18     Patisserie   Item_23_PAT            38.0
# 12571    TXN_4009414     CUST_03      Beverages    Item_2_BEV             6.5
# 12572    TXN_5306010     CUST_11       Butchers    Item_7_BUT            14.0
# 12573    TXN_5167298     CUST_04      Furniture    Item_7_FUR            14.0
# 12574    TXN_2407494     CUST_23           Food   Item_9_FOOD            17.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Customer ID            0
# Category               0
# Item                1213
# Price Per Unit       609
# Quantity             604
# Total Spent          604
# Payment Method         0
# Location               0
# Transaction Date       0
# Discount Applied    4199
# dtype: int64

# %%
df["Item"] = df["Item"].fillna(method="ffill")
df["Price Per Unit"].fillna(df['Price Per Unit'].median(),inplace=True)
df["Quantity"].fillna(df['Quantity'].median(),inplace=True)
df["Total Spent"].fillna(df['Total Spent'].median(),inplace=True)
df["Discount Applied"] = df["Discount Applied"].fillna(method="ffill")
# Out:
# C:\Users\vasud\AppData\Local\Temp\ipykernel_20832\2867417476.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["Item"] = df["Item"].fillna(method="ffill")
# C:\Users\vasud\AppData\Local\Temp\ipykernel_20832\2867417476.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Price Per Unit"].fillna(df['Price Per Unit'].median(),inplace=True)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12575 entries, 0 to 12574
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    12575 non-null  object
#  1   Customer ID       12575 non-null  object
#  2   Category          12575 non-null  object
#  3   Item              12575 non-null  object
#  4   Price Per Unit    12575 non-null  float64
#  5   Quantity          12575 non-null  float64
#  6   Total Spent       12575 non-null  float64
#  7   Payment Method    12575 non-null  object
#  8   Location          12575 non-null  object
#  9   Transaction Date  12575 non-null  object
#  10  Discount Applied  12575 non-null  bool
# dtypes: bool(1), float64(3), object(7)
# memory usage: 994.8+ KB

# %%
df.drop(['Transaction ID',"Customer ID",'Transaction Date'], axis=1, inplace=True)

# %%
df
# Out:
#             Category          Item  Price Per Unit  Quantity  Total Spent  \
# 0         Patisserie   Item_10_PAT            18.5      10.0        185.0
# 1      Milk Products  Item_17_MILK            29.0       9.0        261.0
# 2           Butchers   Item_12_BUT            21.5       2.0         43.0
# 3          Beverages   Item_16_BEV            27.5       9.0        247.5
# 4               Food   Item_6_FOOD            12.5       7.0         87.5
# ...              ...           ...             ...       ...          ...
# 12570     Patisserie   Item_23_PAT            38.0       4.0        152.0
# 12571      Beverages    Item_2_BEV             6.5       9.0         58.5
# 12572       Butchers    Item_7_BUT            14.0      10.0        140.0
# 12573      Furniture    Item_7_FUR            14.0       6.0         84.0
# 12574           Food   Item_9_FOOD            17.0       3.0         51.0
#
#        Payment Method  Location  Discount Applied
# ...

# %%
col= df.select_dtypes(include="object").columns
from sklearn.preprocessing import LabelEncoder
leb=LabelEncoder()
for i in col:
    df[i]=leb.fit_transform(df[i])

bol_leb=LabelEncoder()
df['Discount Applied']=bol_leb.fit_transform(df['Discount Applied'])

# %%
Q1= df['Item'].quantile(0.25)
Q3=df['Item'].quantile(0.75)
IQR=Q3-Q1
IQR
# Out:
# np.float64(98.0)

# %%
lower =Q1-1.5*IQR
upper =Q3+1.5*IQR

# %%
df.drop(df[df["Item"]>upper].index ,inplace=True)
df.drop(df[df["Item"]<lower].index, inplace=True)

# %%
df
# Out:
#        Category  Item  Price Per Unit  Quantity  Total Spent  Payment Method  \
# 0             7     7            18.5      10.0        185.0               2
# 1             6    62            29.0       9.0        261.0               2
# 2             1    17            21.5       2.0         43.0               1
# 3             0    48            27.5       9.0        247.5               1
# 4             4   172            12.5       7.0         87.5               2
# ...         ...   ...             ...       ...          ...             ...
# 12570         7   119            38.0       4.0        152.0               1
# 12571         0   136             6.5       9.0         58.5               0
# 12572         1   177            14.0      10.0        140.0               0
# 12573         5   181            14.0       6.0         84.0               0
# 12574         4   196            17.0       3.0         51.0               0
#
#        Location  Discount Applied
# ...

# %%
x=df.iloc[:,:7]
y=df.iloc[:,7]
x
# Out:
#        Category  Item  Price Per Unit  Quantity  Total Spent  Payment Method  \
# 0             7     7            18.5      10.0        185.0               2
# 1             6    62            29.0       9.0        261.0               2
# 2             1    17            21.5       2.0         43.0               1
# 3             0    48            27.5       9.0        247.5               1
# 4             4   172            12.5       7.0         87.5               2
# ...         ...   ...             ...       ...          ...             ...
# 12570         7   119            38.0       4.0        152.0               1
# 12571         0   136             6.5       9.0         58.5               0
# 12572         1   177            14.0      10.0        140.0               0
# 12573         5   181            14.0       6.0         84.0               0
# 12574         4   196            17.0       3.0         51.0               0
#
#        Location
# 0             1
# ...

# %%
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
st.fit_transform(x)
# Out:
# array([[ 1.53532755, -1.58059316, -0.46261381, ...,  0.60897941,
#          1.23587541,  0.9894788 ],
#        [ 1.0971454 , -0.62174438,  0.53929498, ...,  1.43012255,
#          1.23587541,  0.9894788 ],
#        [-1.09376538, -1.40625702, -0.17635416, ..., -0.92526172,
#          0.01610198,  0.9894788 ],
#        ...,
#        [-1.09376538,  1.38312126, -0.89200329, ...,  0.12277624,
#         -1.20367145,  0.9894788 ],
#        [ 0.65896324,  1.45285572, -0.89200329, ..., -0.4822766 ,
#         -1.20367145,  0.9894788 ],
#        [ 0.22078108,  1.71435993, -0.60574364, ..., -0.8388256 ,
#         -1.20367145,  0.9894788 ]], shape=(12575, 7))

# %%
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 12570    0
# 12571    0
# 12572    0
# 12573    1
# 12574    1
# Name: Discount Applied, Length: 12575, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression
logmodel=LogisticRegression()
logmodel.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=logmodel.predict(x_test)
y_pred[:10]
# Out:
# array([0, 1, 1, 1, 0, 1, 1, 1, 1, 0])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.5107341637953883

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(criterion='entropy')
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
dt_pred=dt.predict(x_test)

# %%
accuracy_score(dt_pred,y_test)
# Out:
# 0.4908560826928174

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(criterion="entropy", n_estimators=50)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=50)

# %%
rf_pred=rf.predict(x_test)

# %%
accuracy_score(y_test,rf_pred)
# Out:
# 0.5017227670288895
