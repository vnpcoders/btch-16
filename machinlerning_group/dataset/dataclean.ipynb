# %%
import numpy as np
import pandas as pd
import matplotlib

# %%
df=pd.read_csv('food_coded.csv')

# %%
print(df.isnull().sum())
# Out:
# GPA                  2
# Gender               0
# breakfast            0
# calories_chicken     0
# calories_day        19
#                     ..
# type_sports         26
# veggies_day          0
# vitamins             0
# waffle_calories      0
# weight               2
# Length: 61, dtype: int64

# %%
df
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %%
df['calories_day'].unique()
# Out:
# array([nan,  3.,  4.,  2.])

# %%
df["calories_day"].fillna(df['calories_day'].median(),inplace=True)
# Out:
# C:\Users\vasud\AppData\Local\Temp\ipykernel_19524\3881181144.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["calories_day"].fillna(df['calories_day'].median(),inplace=True)

# %%
df["type_sports"] = df["type_sports"].fillna(method="ffill")
# Out:
# C:\Users\vasud\AppData\Local\Temp\ipykernel_19524\3481071830.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["type_sports"] = df["type_sports"].fillna(method="ffill")

# %%
null_cols = df.columns[df.isnull().any()]
print(null_cols)
# Out:
# Index(['GPA', 'calories_scone', 'comfort_food', 'comfort_food_reasons',
#        'comfort_food_reasons_coded', 'cook', 'cuisine', 'diet_current',
#        'drink', 'eating_changes', 'employment', 'exercise', 'father_education',
#        'father_profession', 'fav_cuisine', 'fav_food', 'food_childhood',
#        'healthy_meal', 'ideal_diet', 'income', 'life_rewarding',
#        'marital_status', 'meals_dinner_friend', 'mother_education',
#        'mother_profession', 'on_off_campus', 'persian_food',
#        'self_perception_weight', 'soup', 'sports', 'tortilla_calories',
#        'weight'],
#       dtype='object')

# %%
df["comfort_food"] = df["comfort_food"].fillna(method="ffill")
df["comfort_food_reasons"] = df["comfort_food_reasons"].fillna(method="ffill")
df["diet_current"] = df["diet_current"].fillna(method="ffill")
df["eating_changes"] = df["eating_changes"].fillna(method="ffill")
 
df["father_profession"] = df["father_profession"].fillna(method="ffill")
df["fav_cuisine"] = df["fav_cuisine"].fillna(method="ffill")
df["food_childhood"] = df["food_childhood"].fillna(method="ffill")
df["healthy_meal"] = df["healthy_meal"].fillna(method="ffill")

df["ideal_diet"] = df["ideal_diet"].fillna(method="ffill")
df["meals_dinner_friend"] = df["meals_dinner_friend"].fillna(method="ffill")
df["mother_profession"] = df["mother_profession"].fillna(method="ffill")
# Out:
# C:\Users\vasud\AppData\Local\Temp\ipykernel_19524\879442837.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["comfort_food"] = df["comfort_food"].fillna(method="ffill")
# C:\Users\vasud\AppData\Local\Temp\ipykernel_19524\879442837.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["comfort_food_reasons"] = df["comfort_food_reasons"].fillna(method="ffill")
# C:\Users\vasud\AppData\Local\Temp\ipykernel_19524\879442837.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["diet_current"] = df["diet_current"].fillna(method="ffill")
# ...

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['GPA', 'comfort_food', 'comfort_food_reasons', 'diet_current',
#        'eating_changes', 'father_profession', 'fav_cuisine', 'food_childhood',
#        'healthy_meal', 'ideal_diet', 'meals_dinner_friend',
#        'mother_profession', 'type_sports', 'weight'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           125 non-null    float64
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  125 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  125 non-null    object
#  8   comfort_food_reasons          125 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
#change to numarec by the hewlp of pd.to_numarec
df["GPA"] = pd.to_numeric(df["GPA"], errors="coerce")

# %%
df['weight']=pd.to_numeric(df['weight'],errors='coerce')

# %%
df['weight'].fillna(df['weight'].mean(),inplace=True)
# Out:
# C:\Users\vasud\AppData\Local\Temp\ipykernel_19524\463544172.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['weight'].fillna(df['weight'].mean(),inplace=True)

# %%
df['GPA'].unique()
# Out:
# array([2.4  , 3.654, 3.3  , 3.2  , 3.5  , 2.25 , 3.8  , 3.904, 3.4  ,
#        3.6  , 3.1  ,   nan, 4.   , 2.2  , 3.87 , 3.7  , 3.9  , 2.8  ,
#        3.   , 3.65 , 3.89 , 2.9  , 3.605, 3.83 , 3.292, 3.35 , 2.6  ,
#        3.67 , 3.73 , 2.71 , 3.68 , 3.75 , 3.92 , 3.77 , 3.63 , 3.882])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           120 non-null    float64
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  125 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  125 non-null    object
#  8   comfort_food_reasons          125 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
df
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.400       2          1               430           3.0           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2    3.300       1          1               720           4.0           420.0
# 3    3.200       1          1               430           3.0           420.0
# 4    3.500       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120  3.500       1          1               610           4.0           420.0
# 121  3.000       1          1               265           2.0           315.0
# 122  3.882       1          1               720           3.0           420.0
# 123  3.000       2          1               720           4.0           420.0
# 124  3.900       1          1               430           3.0           315.0
#
# ...

# %%
df['GPA'].fillna(df["GPA"].mean(),inplace=True)
# Out:
# C:\Users\vasud\AppData\Local\Temp\ipykernel_19524\1210732238.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['GPA'].fillna(df["GPA"].mean(),inplace=True)

# %%
print(df)
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.400       2          1               430           3.0           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2    3.300       1          1               720           4.0           420.0
# 3    3.200       1          1               430           3.0           420.0
# 4    3.500       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120  3.500       1          1               610           4.0           420.0
# 121  3.000       1          1               265           2.0           315.0
# 122  3.882       1          1               720           3.0           420.0
# 123  3.000       2          1               720           4.0           420.0
# 124  3.900       1          1               430           3.0           315.0
#
# ...

# %%
df.isnull().sum()
# Out:
# GPA                 0
# Gender              0
# breakfast           0
# calories_chicken    0
# calories_day        0
#                    ..
# type_sports         0
# veggies_day         0
# vitamins            0
# waffle_calories     0
# weight              0
# Length: 61, dtype: int64

# %%
null_cols = df.columns[df.isnull().any()]
print(null_cols)
# Out:
# Index(['calories_scone', 'comfort_food_reasons_coded', 'cook', 'cuisine',
#        'drink', 'employment', 'exercise', 'father_education', 'fav_food',
#        'income', 'life_rewarding', 'marital_status', 'mother_education',
#        'on_off_campus', 'persian_food', 'self_perception_weight', 'soup',
#        'sports', 'tortilla_calories'],
#       dtype='object')

# %%
df['calories_scone'].fillna(df["calories_scone"].median(),inplace=True)
df['comfort_food_reasons_coded'].fillna(df["comfort_food_reasons_coded"].median(),inplace=True)
df['cook'].fillna(df["cook"].median(),inplace=True)
df['cuisine'].fillna(df["cuisine"].median(),inplace=True)

df['drink'].fillna(df["drink"].median(),inplace=True)
df['employment'].fillna(df["employment"].median(),inplace=True)
df['exercise'].fillna(df["exercise"].median(),inplace=True)
df['father_education'].fillna(df["father_education"].median(),inplace=True)

df['fav_food'].fillna(df["fav_food"].median(),inplace=True)
df['income'].fillna(df["income"].median(),inplace=True)
df['life_rewarding'].fillna(df["life_rewarding"].median(),inplace=True)
df['marital_status'].fillna(df["marital_status"].median(),inplace=True)


df['mother_education'].fillna(df["mother_education"].median(),inplace=True)
df['on_off_campus'].fillna(df["on_off_campus"].median(),inplace=True)
df['persian_food'].fillna(df["persian_food"].median(),inplace=True)
df['self_perception_weight'].fillna(df["self_perception_weight"].median(),inplace=True)

df['soup'].fillna(df["soup"].median(),inplace=True)
df['sports'].fillna(df["sports"].median(),inplace=True)
df['tortilla_calories'].fillna(df["tortilla_calories"].median(),inplace=True)
# Out:
# C:\Users\vasud\AppData\Local\Temp\ipykernel_19524\2610472110.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['calories_scone'].fillna(df["calories_scone"].median(),inplace=True)
# C:\Users\vasud\AppData\Local\Temp\ipykernel_19524\2610472110.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           125 non-null    float64
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  125 non-null    float64
#  5   calories_scone                125 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  125 non-null    object
#  8   comfort_food_reasons          125 non-null    object
#  9   comfort_food_reasons_coded    125 non-null    float64
#  10  cook                          125 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...
