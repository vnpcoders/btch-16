# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
columns=['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model year', 'origin', 'car name']
df = pd.read_csv(r"D:\btch 16\machinlerning_group\auto+mpg\auto-mpg.data",delim_whitespace=True,header=None,names=columns)
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 1    15.0          8         350.0      165.0  3693.0          11.5
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df['horsepower'].fillna(df['horsepower'].median(), inplace=True)
#
# File c:\Users\vasud\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:6570, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("median", ndim=1))
#    6563 def median(
#    6564     self,
#    (...)   6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\vasud\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:12450, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   12443 def median(
#   12444     self,
#   12445     axis: Axis | None = 0,
#    (...)  12448     **kwargs,
#   12449 ) -> Series | float:
# > 12450     return self._stat_function(
#   12451         "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12452     )
#
# File c:\Users\vasud\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:12396, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12392 nv.validate_func(name, (), kwargs)
#   12394 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12396 return self._reduce(
#   12397     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12398 )
#
# File c:\Users\vasud\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:6468, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6463     # GH#47500 - change to TypeError to match other methods
#    6464     raise TypeError(
#    6465         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6466         "with non-numeric dtypes."
#    6467     )
# -> 6468 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\vasud\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\vasud\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\nanops.py:787, in nanmedian(values, axis, skipna, mask)
#     785     inferred = lib.infer_dtype(values)
#     786     if inferred in ["string", "mixed"]:
# --> 787         raise TypeError(f"Cannot convert {values} to numeric")
#     788 try:
#     789     values = values.astype("f8")
#
# TypeError: Cannot convert ['130.0' '165.0' '150.0' '150.0' '140.0' '198.0' '220.0' '215.0' '225.0'
#  '190.0' '170.0' '160.0' '150.0' '225.0' '95.00' '95.00' '97.00' '85.00'
#  '88.00' '46.00' '87.00' '90.00' '95.00' '113.0' '90.00' '215.0' '200.0'
#  '210.0' '193.0' '88.00' '90.00' '95.00' '?' '100.0' '105.0' '100.0'
#  '88.00' '100.0' '165.0' '175.0' '153.0' '150.0' '180.0' '170.0' '175.0'
#  '110.0' '72.00' '100.0' '88.00' '86.00' '90.00' '70.00' '76.00' '65.00'
#  '69.00' '60.00' '70.00' '95.00' '80.00' '54.00' '90.00' '86.00' '165.0'
#  '175.0' '150.0' '153.0' '150.0' '208.0' '155.0' '160.0' '190.0' '97.00'
#  '150.0' '130.0' '140.0' '150.0' '112.0' '76.00' '87.00' '69.00' '86.00'
#  '92.00' '97.00' '80.00' '88.00' '175.0' '150.0' '145.0' '137.0' '150.0'
#  '198.0' '150.0' '158.0' '150.0' '215.0' '225.0' '175.0' '105.0' '100.0'
#  '100.0' '88.00' '95.00' '46.00' '150.0' '167.0' '170.0' '180.0' '100.0'
#  '88.00' '72.00' '94.00' '90.00' '85.00' '107.0' '90.00' '145.0' '230.0'
#  '49.00' '75.00' '91.00' '112.0' '150.0' '110.0' '122.0' '180.0' '95.00'
#  '?' '100.0' '100.0' '67.00' '80.00' '65.00' '75.00' '100.0' '110.0'
#  '105.0' '140.0' '150.0' '150.0' '140.0' '150.0' '83.00' '67.00' '78.00'
#  '52.00' '61.00' '75.00' '75.00' '75.00' '97.00' '93.00' '67.00' '95.00'
#  '105.0' '72.00' '72.00' '170.0' '145.0' '150.0' '148.0' '110.0' '105.0'
#  '110.0' '95.00' '110.0' '110.0' '129.0' '75.00' '83.00' '100.0' '78.00'
#  '96.00' '71.00' '97.00' '97.00' '70.00' '90.00' '95.00' '88.00' '98.00'
#  '115.0' '53.00' '86.00' '81.00' '92.00' '79.00' '83.00' '140.0' '150.0'
#  '120.0' '152.0' '100.0' '105.0' '81.00' '90.00' '52.00' '60.00' '70.00'
#  '53.00' '100.0' '78.00' '110.0' '95.00' '71.00' '70.00' '75.00' '72.00'
#  '102.0' '150.0' '88.00' '108.0' '120.0' '180.0' '145.0' '130.0' '150.0'
#  '68.00' '80.00' '58.00' '96.00' '70.00' '145.0' '110.0' '145.0' '130.0'
#  '110.0' '105.0' '100.0' '98.00' '180.0' '170.0' '190.0' '149.0' '78.00'
#  '88.00' '75.00' '89.00' '63.00' '83.00' '67.00' '78.00' '97.00' '110.0'
#  '110.0' '48.00' '66.00' '52.00' '70.00' '60.00' '110.0' '140.0' '139.0'
#  '105.0' '95.00' '85.00' '88.00' '100.0' '90.00' '105.0' '85.00' '110.0'
#  '120.0' '145.0' '165.0' '139.0' '140.0' '68.00' '95.00' '97.00' '75.00'
#  '95.00' '105.0' '85.00' '97.00' '103.0' '125.0' '115.0' '133.0' '71.00'
#  '68.00' '115.0' '85.00' '88.00' '90.00' '110.0' '130.0' '129.0' '138.0'
#  '135.0' '155.0' '142.0' '125.0' '150.0' '71.00' '65.00' '80.00' '80.00'
#  '77.00' '125.0' '71.00' '90.00' '70.00' '70.00' '65.00' '69.00' '90.00'
#  '115.0' '115.0' '90.00' '76.00' '60.00' '70.00' '65.00' '90.00' '88.00'
#  '90.00' '90.00' '78.00' '90.00' '75.00' '92.00' '75.00' '65.00' '105.0'
#  '65.00' '48.00' '48.00' '67.00' '67.00' '67.00' '?' '67.00' '62.00'
#  '132.0' '100.0' '88.00' '?' '72.00' '84.00' '84.00' '92.00' '110.0'
#  '84.00' '58.00' '64.00' '60.00' '67.00' '65.00' '62.00' '68.00' '63.00'
#  '65.00' '65.00' '74.00' '?' '75.00' '75.00' '100.0' '74.00' '80.00'
#  '76.00' '116.0' '120.0' '110.0' '105.0' '88.00' '85.00' '88.00' '88.00'
#  '88.00' '85.00' '84.00' '90.00' '92.00' '?' '74.00' '68.00' '68.00'
#  '63.00' '70.00' '88.00' '75.00' '70.00' '67.00' '67.00' '67.00' '110.0'
#  '85.00' '92.00' '112.0' '96.00' '84.00' '90.00' '86.00' '52.00' '84.00'
#  '79.00' '82.00'] to numeric

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
df.select_dtypes(include=["object"]).columns
# Out:
# Index(['horsepower', 'car name'], dtype='object')

# %%
df['horsepower'].unique()
df['horsepower'].replace('?', np.nan, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 df['horsepower'].unique()
#       2 df['horsepower'].replace('?', np.nan, inplace=True)
# ----> 3 df['horsepower'].fillna(df['horsepower'].median(), inplace=True)
#
# File c:\Users\vasud\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:6570, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("median", ndim=1))
#    6563 def median(
#    6564     self,
#    (...)   6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\vasud\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:12450, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   12443 def median(
#   12444     self,
#   12445     axis: Axis | None = 0,
#    (...)  12448     **kwargs,
#   12449 ) -> Series | float:
# > 12450     return self._stat_function(
#   12451         "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12452     )
#
# File c:\Users\vasud\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:12396, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12392 nv.validate_func(name, (), kwargs)
#   12394 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12396 return self._reduce(
#   12397     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12398 )
#
# File c:\Users\vasud\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:6468, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6463     # GH#47500 - change to TypeError to match other methods
#    6464     raise TypeError(
#    6465         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6466         "with non-numeric dtypes."
#    6467     )
# -> 6468 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\vasud\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\vasud\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\nanops.py:787, in nanmedian(values, axis, skipna, mask)
#     785     inferred = lib.infer_dtype(values)
#     786     if inferred in ["string", "mixed"]:
# --> 787         raise TypeError(f"Cannot convert {values} to numeric")
#     788 try:
#     789     values = values.astype("f8")
#
# TypeError: Cannot convert ['130.0' '165.0' '150.0' '150.0' '140.0' '198.0' '220.0' '215.0' '225.0'
#  '190.0' '170.0' '160.0' '150.0' '225.0' '95.00' '95.00' '97.00' '85.00'
#  '88.00' '46.00' '87.00' '90.00' '95.00' '113.0' '90.00' '215.0' '200.0'
#  '210.0' '193.0' '88.00' '90.00' '95.00' nan '100.0' '105.0' '100.0'
#  '88.00' '100.0' '165.0' '175.0' '153.0' '150.0' '180.0' '170.0' '175.0'
#  '110.0' '72.00' '100.0' '88.00' '86.00' '90.00' '70.00' '76.00' '65.00'
#  '69.00' '60.00' '70.00' '95.00' '80.00' '54.00' '90.00' '86.00' '165.0'
#  '175.0' '150.0' '153.0' '150.0' '208.0' '155.0' '160.0' '190.0' '97.00'
#  '150.0' '130.0' '140.0' '150.0' '112.0' '76.00' '87.00' '69.00' '86.00'
#  '92.00' '97.00' '80.00' '88.00' '175.0' '150.0' '145.0' '137.0' '150.0'
#  '198.0' '150.0' '158.0' '150.0' '215.0' '225.0' '175.0' '105.0' '100.0'
#  '100.0' '88.00' '95.00' '46.00' '150.0' '167.0' '170.0' '180.0' '100.0'
#  '88.00' '72.00' '94.00' '90.00' '85.00' '107.0' '90.00' '145.0' '230.0'
#  '49.00' '75.00' '91.00' '112.0' '150.0' '110.0' '122.0' '180.0' '95.00'
#  nan '100.0' '100.0' '67.00' '80.00' '65.00' '75.00' '100.0' '110.0'
#  '105.0' '140.0' '150.0' '150.0' '140.0' '150.0' '83.00' '67.00' '78.00'
#  '52.00' '61.00' '75.00' '75.00' '75.00' '97.00' '93.00' '67.00' '95.00'
#  '105.0' '72.00' '72.00' '170.0' '145.0' '150.0' '148.0' '110.0' '105.0'
#  '110.0' '95.00' '110.0' '110.0' '129.0' '75.00' '83.00' '100.0' '78.00'
#  '96.00' '71.00' '97.00' '97.00' '70.00' '90.00' '95.00' '88.00' '98.00'
#  '115.0' '53.00' '86.00' '81.00' '92.00' '79.00' '83.00' '140.0' '150.0'
#  '120.0' '152.0' '100.0' '105.0' '81.00' '90.00' '52.00' '60.00' '70.00'
#  '53.00' '100.0' '78.00' '110.0' '95.00' '71.00' '70.00' '75.00' '72.00'
#  '102.0' '150.0' '88.00' '108.0' '120.0' '180.0' '145.0' '130.0' '150.0'
#  '68.00' '80.00' '58.00' '96.00' '70.00' '145.0' '110.0' '145.0' '130.0'
#  '110.0' '105.0' '100.0' '98.00' '180.0' '170.0' '190.0' '149.0' '78.00'
#  '88.00' '75.00' '89.00' '63.00' '83.00' '67.00' '78.00' '97.00' '110.0'
#  '110.0' '48.00' '66.00' '52.00' '70.00' '60.00' '110.0' '140.0' '139.0'
#  '105.0' '95.00' '85.00' '88.00' '100.0' '90.00' '105.0' '85.00' '110.0'
#  '120.0' '145.0' '165.0' '139.0' '140.0' '68.00' '95.00' '97.00' '75.00'
#  '95.00' '105.0' '85.00' '97.00' '103.0' '125.0' '115.0' '133.0' '71.00'
#  '68.00' '115.0' '85.00' '88.00' '90.00' '110.0' '130.0' '129.0' '138.0'
#  '135.0' '155.0' '142.0' '125.0' '150.0' '71.00' '65.00' '80.00' '80.00'
#  '77.00' '125.0' '71.00' '90.00' '70.00' '70.00' '65.00' '69.00' '90.00'
#  '115.0' '115.0' '90.00' '76.00' '60.00' '70.00' '65.00' '90.00' '88.00'
#  '90.00' '90.00' '78.00' '90.00' '75.00' '92.00' '75.00' '65.00' '105.0'
#  '65.00' '48.00' '48.00' '67.00' '67.00' '67.00' nan '67.00' '62.00'
#  '132.0' '100.0' '88.00' nan '72.00' '84.00' '84.00' '92.00' '110.0'
#  '84.00' '58.00' '64.00' '60.00' '67.00' '65.00' '62.00' '68.00' '63.00'
#  '65.00' '65.00' '74.00' nan '75.00' '75.00' '100.0' '74.00' '80.00'
#  '76.00' '116.0' '120.0' '110.0' '105.0' '88.00' '85.00' '88.00' '88.00'
#  '88.00' '85.00' '84.00' '90.00' '92.00' nan '74.00' '68.00' '68.00'
#  '63.00' '70.00' '88.00' '75.00' '70.00' '67.00' '67.00' '67.00' '110.0'
#  '85.00' '92.00' '112.0' '96.00' '84.00' '90.00' '86.00' '52.00' '84.00'
#  '79.00' '82.00'] to numeric

# %%
df['horsepower'].unique()
# Out:
# array([130. , 165. , 150. , 140. , 198. , 220. , 215. , 225. , 190. ,
#        170. , 160. ,  95. ,  97. ,  85. ,  88. ,  46. ,  87. ,  90. ,
#        113. , 200. , 210. , 193. ,  93.5, 100. , 105. , 175. , 153. ,
#        180. , 110. ,  72. ,  86. ,  70. ,  76. ,  65. ,  69. ,  60. ,
#         80. ,  54. , 208. , 155. , 112. ,  92. , 145. , 137. , 158. ,
#        167. ,  94. , 107. , 230. ,  49. ,  75. ,  91. , 122. ,  67. ,
#         83. ,  78. ,  52. ,  61. ,  93. , 148. , 129. ,  96. ,  71. ,
#         98. , 115. ,  53. ,  81. ,  79. , 120. , 152. , 102. , 108. ,
#         68. ,  58. , 149. ,  89. ,  63. ,  48. ,  66. , 139. , 103. ,
#        125. , 133. , 138. , 135. , 142. ,  77. ,  62. , 132. ,  84. ,
#         64. ,  74. , 116. ,  82. ])

# %%
df['horsepower'].fillna(df['horsepower'].median(), inplace=True)

# %%
df.select_dtypes(include=['object']).columns
# Out:
# Index(['car name'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
Leb_enc=LabelEncoder()
df["car name"]= Leb_enc.fit_transform(df['car name'])

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      model year  origin  car name
# 0            70       1        49
# 1            70       1        36
# 2            70       1       231
# 3            70       1        14
# 4            70       1       161
# ..          ...     ...       ...
# 393          82       1       153
# 394          82       2       301
# 395          82       1       119
# 396          82       1       159
# 397          82       1        69
#
# [398 rows x 9 columns]

# %%
x=df.drop('mpg',axis=1)
y=df['mpg']

# %%
x
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0            8         307.0       130.0  3504.0          12.0          70
# 1            8         350.0       165.0  3693.0          11.5          70
# 2            8         318.0       150.0  3436.0          11.0          70
# 3            8         304.0       150.0  3433.0          12.0          70
# 4            8         302.0       140.0  3449.0          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0  2790.0          15.6          82
# 394          4          97.0        52.0  2130.0          24.6          82
# 395          4         135.0        84.0  2295.0          11.6          82
# 396          4         120.0        79.0  2625.0          18.6          82
# 397          4         119.0        82.0  2720.0          19.4          82
#
#      origin  car name
# 0         1        49
# 1         1        36
# 2         1       231
# 3         1        14
# 4         1       161
# ..      ...       ...
# 393       1       153
# 394       2       301
# 395       1       119
# 396       1       159
# 397       1        69
#
# [398 rows x 8 columns]

# %%
y
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
linreg=LinearRegression()
linreg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=linreg.predict(x_test)
y_pred[:10]
# Out:
# array([21.1701094 , 26.90083254, 26.75471071, 29.78125512, 16.03747428,
#        30.81497551, 19.34613951, 22.57835401, 17.95842948, 23.50908879])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)*100
# Out:
# 81.10664383119801
